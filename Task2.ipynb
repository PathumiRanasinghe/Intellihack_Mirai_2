# %% [markdown]
# <a href="https://colab.research.google.com/github/PathumiRanasinghe/Intellihack_Mirai_2/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/Mirai - ML hackathon/customer_behavior_analytcis.csv")

# %%
df
# Out:
#      total_purchases  avg_cart_value  total_time_spent  product_click  \
# 0                7.0          129.34             52.17           18.0
# 1               22.0           24.18              9.19           15.0
# 2                2.0           32.18             90.69           50.0
# 3               25.0           26.85             11.22           16.0
# 4                7.0          125.45             34.19           30.0
# ..               ...             ...               ...            ...
# 994              5.0           64.64             72.70           50.0
# 995              5.0           68.36             75.41           43.0
# 996             18.0           19.53             28.77           18.0
# 997              4.0           28.97             72.27           57.0
# 998             29.0           39.29              9.99           16.0
#
#      discount_counts customer_id
# 0                0.0     CM00000
# 1                7.0     CM00001
# ...

# %%
df.describe()
# Out:
#        total_purchases  avg_cart_value  total_time_spent  product_click  \
# count       979.000000      979.000000        999.000000     979.000000
# mean         11.570991       75.457978         49.348759      28.237998
# std           7.016327       55.067835         32.730973      16.296384
# min           0.000000       10.260000          5.120000       4.000000
# 25%           6.000000       33.130000         22.375000      16.000000
# 50%          10.000000       49.380000         40.360000      21.000000
# 75%          17.000000      121.255000         77.170000      45.000000
# max          32.000000      199.770000        119.820000      73.000000
#
#        discount_counts
# count       999.000000
# mean          4.313313
# std           4.532772
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           8.000000
# max          21.000000
